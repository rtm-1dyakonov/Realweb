# %%
import pandas as pd

'''
В процессе работы с фреймами в pandas или обучении могут быть исключения, 
которые снижают читабельность кода. Выключим их вывод:
'''

import warnings
warnings.filterwarnings("ignore")

# %%
### Текущая ячейка отвечает за кол-во столбцов, отображаемых при выводе фрейма. Уберём ограничение ###

pd.set_option('display.max_columns', None)

# %%
### Прочитаем таблицу .XLSX и выведем первые 5 строчек ###

df = pd.read_excel("auto_complectations.xlsx")
df.head()
# Out:
#   brand     model               complect        type_car  seats  doors  \
# 0  Audi  A3 Sedan          1.4 TFSI 7AMT  Седан класса C      5      4
# 1  Audi  A3 Sedan    sport 1.4 TFSI 7AMT  Седан класса C      5      4
# 2  Audi  A3 Sedan          2.0 TFSI 7AMT  Седан класса C      5      4
# 3  Audi  A3 Sedan  2.0 TFSI 7AMT quattro  Седан класса C      5      4
# 4  Audi  A3 Sedan    sport 2.0 TFSI 7AMT  Седан класса C      5      4
#
#                Двигатель   Мощность Крутящий момент двигателя  \
# 0  бензиновый (1395 см³)  150 л. с.                   250 Н·м
# 1  бензиновый (1395 см³)  150 л. с.                   250 Н·м
# 2  бензиновый (1984 см³)  190 л. с.                   320 Н·м
# 3  бензиновый (1984 см³)  190 л. с.                   320 Н·м
# 4  бензиновый (1984 см³)  190 л. с.                   320 Н·м
#
#                  Коробка передач    Привод Разгон до сотни  \
# 0  роботизированная (7 ступеней)  передний     8.2 секунды
# 1  роботизированная (7 ступеней)  передний     8.2 секунды
# 2  роботизированная (7 ступеней)  передний     6.8 секунды
# 3  роботизированная (7 ступеней)    полный     6.2 секунды
# 4  роботизированная (7 ступеней)  передний     6.8 секунды
#
#   Максимальная скорость Расход топлива (л/100 км)\nгород / трасса / смешанный  \
# 0              224 км/ч                                    5.9 / 4.1 / 4.8
# 1              224 км/ч                                    5.9 / 4.1 / 4.8
# 2              250 км/ч                                    7.2 / 4.7 / 5.6
# 3              242 км/ч                                    7.2 / 4.8 / 5.7
# 4              242 км/ч                                    7.2 / 4.7 / 5.6
#
#   Дорожный просвет Габариты (длина × ширина × высота) Колёсная база  \
# 0           165 мм                 4458 × 1796 × 1416       2637 мм
# 1           165 мм                 4458 × 1796 × 1416       2637 мм
# 2           165 мм                 4458 × 1796 × 1416       2637 мм
# 3           165 мм                 4458 × 1796 × 1416       2637 мм
# 4           165 мм                 4458 × 1796 × 1416       2637 мм
#
#   Объём багажника Объём багажника максимальный Объём топливного бака  \
# 0           425 л                        880 л                  50 л
# 1           425 л                        880 л                  50 л
# 2           425 л                        880 л                  50 л
# 3           390 л                        845 л                  55 л
# 4           425 л                        880 л                  50 л
#
#   Масса автомобиля
# 0          1320 кг
# 1          1320 кг
# 2          1395 кг
# 3          1465 кг
# 4          1395 кг

# %% [markdown]
# ### Посмотрим на размер данных, названия признаков и их типы ↓

# %%
print(df.shape)
print(df.info())
# Out:
# (1703, 21)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1703 entries, 0 to 1702
# Data columns (total 21 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   brand                                                 1703 non-null   object
#  1   model                                                 1703 non-null   object
#  2   complect                                              1703 non-null   object
#  3   type_car                                              1703 non-null   object
#  4   seats                                                 1703 non-null   int64
#  5   doors                                                 1703 non-null   int64
#  6   Двигатель                                             1703 non-null   object
#  7   Мощность                                              1703 non-null   object
#  8   Крутящий момент двигателя                             1703 non-null   object
#  9   Коробка передач                                       1703 non-null   object
#  10  Привод                                                1703 non-null   object
#  11  Разгон до сотни                                       1703 non-null   object
#  12  Максимальная скорость                                 1703 non-null   object
#  13  Расход топлива (л/100 км)
# город / трасса / смешанный  1703 non-null   object
#  14  Дорожный просвет                                      1703 non-null   object
#  15  Габариты (длина × ширина × высота)                    1703 non-null   object
#  16  Колёсная база                                         1703 non-null   object
#  17  Объём багажника                                       1703 non-null   object
#  18  Объём багажника максимальный                          1703 non-null   object
#  19  Объём топливного бака                                 1703 non-null   object
#  20  Масса автомобиля                                      1703 non-null   object
# dtypes: int64(2), object(19)
# memory usage: 279.5+ KB
# None

# %% [markdown]
# Всё говорит о том, что пропущенных значений в строчках нет. Проверим это позднее

# %%
'''
В фрейме имеются строчки с размерностями, а это не позволит использовать соответствующие столбцы
в процессе обучения моделей классификации. Так что сохраним только значения:
'''

only_values = ['Мощность', 'Крутящий момент двигателя', 'Разгон до сотни', 
               'Максимальная скорость', 'Дорожный просвет', 'Колёсная база', 'Объём багажника', 
               'Объём багажника максимальный', 'Объём топливного бака', 'Масса автомобиля']

for col in only_values:
    df[f"{col}"] = df[f"{col}"].apply(lambda x: x.split(' ')[0])

df
# Out:
#       brand     model               complect           type_car  seats  doors  \
# 0      Audi  A3 Sedan          1.4 TFSI 7AMT     Седан класса C      5      4
# 1      Audi  A3 Sedan    sport 1.4 TFSI 7AMT     Седан класса C      5      4
# 2      Audi  A3 Sedan          2.0 TFSI 7AMT     Седан класса C      5      4
# 3      Audi  A3 Sedan  2.0 TFSI 7AMT quattro     Седан класса C      5      4
# 4      Audi  A3 Sedan    sport 2.0 TFSI 7AMT     Седан класса C      5      4
# ...     ...       ...                    ...                ...    ...    ...
# 1698  Volvo      XC90      D5 AT 5S R-Design  Большой кроссовер      5      5
# 1699  Volvo      XC90      T6 AT 7S R-Design  Большой кроссовер      7      5
# 1700  Volvo      XC90      D5 AT 7S R-Design  Большой кроссовер      7      5
# 1701  Volvo      XC90   T8 AT 7S Inscription  Большой кроссовер      7      5
# 1702  Volvo      XC90      T8 AT 7S R-Design  Большой кроссовер      7      5
#
#                   Двигатель Мощность Крутящий момент двигателя  \
# 0     бензиновый (1395 см³)      150                       250
# 1     бензиновый (1395 см³)      150                       250
# 2     бензиновый (1984 см³)      190                       320
# 3     бензиновый (1984 см³)      190                       320
# 4     бензиновый (1984 см³)      190                       320
# ...                     ...      ...                       ...
# 1698   дизельный (1969 см³)      235                       480
# 1699  бензиновый (1969 см³)      320                       400
# 1700   дизельный (1969 см³)      235                       480
# 1701   гибридный (1969 см³)      407                       640
# 1702   гибридный (1969 см³)      407                       640
#
#                     Коробка передач    Привод Разгон до сотни  \
# 0     роботизированная (7 ступеней)  передний             8.2
# 1     роботизированная (7 ступеней)  передний             8.2
# 2     роботизированная (7 ступеней)  передний             6.8
# 3     роботизированная (7 ступеней)    полный             6.2
# 4     роботизированная (7 ступеней)  передний             6.8
# ...                             ...       ...             ...
# 1698    автоматическая (8 ступеней)    полный             7.8
# 1699    автоматическая (8 ступеней)    полный             6.5
# 1700    автоматическая (8 ступеней)    полный             7.8
# 1701    автоматическая (8 ступеней)    полный             5.6
# 1702    автоматическая (8 ступеней)    полный             5.6
#
#      Максимальная скорость  \
# 0                      224
# 1                      224
# 2                      250
# 3                      242
# 4                      242
# ...                    ...
# 1698                   220
# 1699                   230
# 1700                   220
# 1701                   230
# 1702                   230
#
#      Расход топлива (л/100 км)\nгород / трасса / смешанный Дорожный просвет  \
# 0                                       5.9 / 4.1 / 4.8                 165
# 1                                       5.9 / 4.1 / 4.8                 165
# 2                                       7.2 / 4.7 / 5.6                 165
# 3                                       7.2 / 4.8 / 5.7                 165
# 4                                       7.2 / 4.7 / 5.6                 165
# ...                                                 ...                 ...
# 1698                                    6.4 / 5.5 / 5.8                 237
# 1699                                        0 / 0 / 8.3                 237
# 1700                                    6.4 / 5.5 / 5.8                 237
# 1701                                        0 / 0 / 2.1                 237
# 1702                                        0 / 0 / 2.1                 237
#
#      Габариты (длина × ширина × высота) Колёсная база Объём багажника  \
# 0                    4458 × 1796 × 1416          2637             425
# 1                    4458 × 1796 × 1416          2637             425
# 2                    4458 × 1796 × 1416          2637             425
# 3                    4458 × 1796 × 1416          2637             390
# 4                    4458 × 1796 × 1416          2637             425
# ...                                 ...           ...             ...
# 1698                 4950 × 2008 × 1776          2984             721
# 1699                 4950 × 2008 × 1776          2984             692
# 1700                 4950 × 2008 × 1776          2984             692
# 1701                 4950 × 2008 × 1776          2984             640
# 1702                 4950 × 2008 × 1776          2984             640
#
#      Объём багажника максимальный Объём топливного бака Масса автомобиля
# 0                             880                    50             1320
# 1                             880                    50             1320
# 2                             880                    50             1395
# 3                             845                    55             1465
# 4                             880                    50             1395
# ...                           ...                   ...              ...
# 1698                         1899                    71             1969
# 1699                         1899                    71             2004
# 1700                         1899                    71             2009
# 1701                         1899                    70             2350
# 1702                         1899                    70             2350
#
# [1703 rows x 21 columns]

# %%
'''
Также есть 2 столбца, включающие непрерывную величину и категориальную - впоследствии дискретную - величины
одновременно. Разделим каждый на 2, записывая в столбец "тип" категорию, а в "значение" - непрерывное значение.
В конце избавимся от изначальных столбцов, так как они будут просто дублировать информацию:
'''

split_columns = ['Двигатель', 'Коробка передач']

for col in split_columns:
    df[f"{col} тип"] = df[f"{col}"].apply(lambda x: x.split(' ')[0])
    df[f"{col} значение"] = df[f"{col}"].apply(lambda x: x.split(' ')[1].split('(')[1])

df = df.drop(split_columns, 1)

df
# Out:
#       brand     model               complect           type_car  seats  doors  \
# 0      Audi  A3 Sedan          1.4 TFSI 7AMT     Седан класса C      5      4
# 1      Audi  A3 Sedan    sport 1.4 TFSI 7AMT     Седан класса C      5      4
# 2      Audi  A3 Sedan          2.0 TFSI 7AMT     Седан класса C      5      4
# 3      Audi  A3 Sedan  2.0 TFSI 7AMT quattro     Седан класса C      5      4
# 4      Audi  A3 Sedan    sport 2.0 TFSI 7AMT     Седан класса C      5      4
# ...     ...       ...                    ...                ...    ...    ...
# 1698  Volvo      XC90      D5 AT 5S R-Design  Большой кроссовер      5      5
# 1699  Volvo      XC90      T6 AT 7S R-Design  Большой кроссовер      7      5
# 1700  Volvo      XC90      D5 AT 7S R-Design  Большой кроссовер      7      5
# 1701  Volvo      XC90   T8 AT 7S Inscription  Большой кроссовер      7      5
# 1702  Volvo      XC90      T8 AT 7S R-Design  Большой кроссовер      7      5
#
#      Мощность Крутящий момент двигателя    Привод Разгон до сотни  \
# 0         150                       250  передний             8.2
# 1         150                       250  передний             8.2
# 2         190                       320  передний             6.8
# 3         190                       320    полный             6.2
# 4         190                       320  передний             6.8
# ...       ...                       ...       ...             ...
# 1698      235                       480    полный             7.8
# 1699      320                       400    полный             6.5
# 1700      235                       480    полный             7.8
# 1701      407                       640    полный             5.6
# 1702      407                       640    полный             5.6
#
#      Максимальная скорость  \
# 0                      224
# 1                      224
# 2                      250
# 3                      242
# 4                      242
# ...                    ...
# 1698                   220
# 1699                   230
# 1700                   220
# 1701                   230
# 1702                   230
#
#      Расход топлива (л/100 км)\nгород / трасса / смешанный Дорожный просвет  \
# 0                                       5.9 / 4.1 / 4.8                 165
# 1                                       5.9 / 4.1 / 4.8                 165
# 2                                       7.2 / 4.7 / 5.6                 165
# 3                                       7.2 / 4.8 / 5.7                 165
# 4                                       7.2 / 4.7 / 5.6                 165
# ...                                                 ...                 ...
# 1698                                    6.4 / 5.5 / 5.8                 237
# 1699                                        0 / 0 / 8.3                 237
# 1700                                    6.4 / 5.5 / 5.8                 237
# 1701                                        0 / 0 / 2.1                 237
# 1702                                        0 / 0 / 2.1                 237
#
#      Габариты (длина × ширина × высота) Колёсная база Объём багажника  \
# 0                    4458 × 1796 × 1416          2637             425
# 1                    4458 × 1796 × 1416          2637             425
# 2                    4458 × 1796 × 1416          2637             425
# 3                    4458 × 1796 × 1416          2637             390
# 4                    4458 × 1796 × 1416          2637             425
# ...                                 ...           ...             ...
# 1698                 4950 × 2008 × 1776          2984             721
# 1699                 4950 × 2008 × 1776          2984             692
# 1700                 4950 × 2008 × 1776          2984             692
# 1701                 4950 × 2008 × 1776          2984             640
# 1702                 4950 × 2008 × 1776          2984             640
#
#      Объём багажника максимальный Объём топливного бака Масса автомобиля  \
# 0                             880                    50             1320
# 1                             880                    50             1320
# 2                             880                    50             1395
# 3                             845                    55             1465
# 4                             880                    50             1395
# ...                           ...                   ...              ...
# 1698                         1899                    71             1969
# 1699                         1899                    71             2004
# 1700                         1899                    71             2009
# 1701                         1899                    70             2350
# 1702                         1899                    70             2350
#
#      Двигатель тип Двигатель значение Коробка передач тип  \
# 0       бензиновый               1395    роботизированная
# 1       бензиновый               1395    роботизированная
# 2       бензиновый               1984    роботизированная
# 3       бензиновый               1984    роботизированная
# 4       бензиновый               1984    роботизированная
# ...            ...                ...                 ...
# 1698     дизельный               1969      автоматическая
# 1699    бензиновый               1969      автоматическая
# 1700     дизельный               1969      автоматическая
# 1701     гибридный               1969      автоматическая
# 1702     гибридный               1969      автоматическая
#
#      Коробка передач значение
# 0                           7
# 1                           7
# 2                           7
# 3                           7
# 4                           7
# ...                       ...
# 1698                        8
# 1699                        8
# 1700                        8
# 1701                        8
# 1702                        8
#
# [1703 rows x 23 columns]

# %%
'''
Последняя итерация на данном этапе. Необходимо произвести очень похожую процедуру, как в предыдущей
ячейке, только теперь разбиение проводить на 3 столбца, а символ разбиения строки не просто пробел, а 
комбинация символов " / " и " × ". Также не забываем избавиться от изначальнх столбцов:
'''


df["Расход на 100 км город"] = df["Расход топлива (л/100 км)\nгород / трасса / смешанный"].apply(lambda x: x.split(' / ')[0])
df["Расход на 100 км трасса"] = df["Расход топлива (л/100 км)\nгород / трасса / смешанный"].apply(lambda x: x.split(' / ')[1])
df["Расход на 100 км смешанный"] = df["Расход топлива (л/100 км)\nгород / трасса / смешанный"].apply(lambda x: x.split(' / ')[2])

df["Габариты длина"] = df["Габариты (длина × ширина × высота)"].apply(lambda x: x.split(' × ')[0])
df["Габариты ширина"] = df["Габариты (длина × ширина × высота)"].apply(lambda x: x.split(' × ')[1])
df["Габариты высота"] = df["Габариты (длина × ширина × высота)"].apply(lambda x: x.split(' × ')[2])

df = df.drop(['Расход топлива (л/100 км)\nгород / трасса / смешанный', 'Габариты (длина × ширина × высота)'], 1)

df
# Out:
#       brand     model               complect           type_car  seats  doors  \
# 0      Audi  A3 Sedan          1.4 TFSI 7AMT     Седан класса C      5      4
# 1      Audi  A3 Sedan    sport 1.4 TFSI 7AMT     Седан класса C      5      4
# 2      Audi  A3 Sedan          2.0 TFSI 7AMT     Седан класса C      5      4
# 3      Audi  A3 Sedan  2.0 TFSI 7AMT quattro     Седан класса C      5      4
# 4      Audi  A3 Sedan    sport 2.0 TFSI 7AMT     Седан класса C      5      4
# ...     ...       ...                    ...                ...    ...    ...
# 1698  Volvo      XC90      D5 AT 5S R-Design  Большой кроссовер      5      5
# 1699  Volvo      XC90      T6 AT 7S R-Design  Большой кроссовер      7      5
# 1700  Volvo      XC90      D5 AT 7S R-Design  Большой кроссовер      7      5
# 1701  Volvo      XC90   T8 AT 7S Inscription  Большой кроссовер      7      5
# 1702  Volvo      XC90      T8 AT 7S R-Design  Большой кроссовер      7      5
#
#      Мощность Крутящий момент двигателя    Привод Разгон до сотни  \
# 0         150                       250  передний             8.2
# 1         150                       250  передний             8.2
# 2         190                       320  передний             6.8
# 3         190                       320    полный             6.2
# 4         190                       320  передний             6.8
# ...       ...                       ...       ...             ...
# 1698      235                       480    полный             7.8
# 1699      320                       400    полный             6.5
# 1700      235                       480    полный             7.8
# 1701      407                       640    полный             5.6
# 1702      407                       640    полный             5.6
#
#      Максимальная скорость Дорожный просвет Колёсная база Объём багажника  \
# 0                      224              165          2637             425
# 1                      224              165          2637             425
# 2                      250              165          2637             425
# 3                      242              165          2637             390
# 4                      242              165          2637             425
# ...                    ...              ...           ...             ...
# 1698                   220              237          2984             721
# 1699                   230              237          2984             692
# 1700                   220              237          2984             692
# 1701                   230              237          2984             640
# 1702                   230              237          2984             640
#
#      Объём багажника максимальный Объём топливного бака Масса автомобиля  \
# 0                             880                    50             1320
# 1                             880                    50             1320
# 2                             880                    50             1395
# 3                             845                    55             1465
# 4                             880                    50             1395
# ...                           ...                   ...              ...
# 1698                         1899                    71             1969
# 1699                         1899                    71             2004
# 1700                         1899                    71             2009
# 1701                         1899                    70             2350
# 1702                         1899                    70             2350
#
#      Двигатель тип Двигатель значение Коробка передач тип  \
# 0       бензиновый               1395    роботизированная
# 1       бензиновый               1395    роботизированная
# 2       бензиновый               1984    роботизированная
# 3       бензиновый               1984    роботизированная
# 4       бензиновый               1984    роботизированная
# ...            ...                ...                 ...
# 1698     дизельный               1969      автоматическая
# 1699    бензиновый               1969      автоматическая
# 1700     дизельный               1969      автоматическая
# 1701     гибридный               1969      автоматическая
# 1702     гибридный               1969      автоматическая
#
#      Коробка передач значение Расход на 100 км город Расход на 100 км трасса  \
# 0                           7                    5.9                     4.1
# 1                           7                    5.9                     4.1
# 2                           7                    7.2                     4.7
# 3                           7                    7.2                     4.8
# 4                           7                    7.2                     4.7
# ...                       ...                    ...                     ...
# 1698                        8                    6.4                     5.5
# 1699                        8                      0                       0
# 1700                        8                    6.4                     5.5
# 1701                        8                      0                       0
# 1702                        8                      0                       0
#
#      Расход на 100 км смешанный Габариты длина Габариты ширина Габариты высота
# 0                           4.8           4458            1796            1416
# 1                           4.8           4458            1796            1416
# 2                           5.6           4458            1796            1416
# 3                           5.7           4458            1796            1416
# 4                           5.6           4458            1796            1416
# ...                         ...            ...             ...             ...
# 1698                        5.8           4950            2008            1776
# 1699                        8.3           4950            2008            1776
# 1700                        5.8           4950            2008            1776
# 1701                        2.1           4950            2008            1776
# 1702                        2.1           4950            2008            1776
#
# [1703 rows x 27 columns]

# %%
'''
Кроме перевода всех изначальных и получившихся столбцов с непрерывными значениями из строковых
в числовые, всё таки проверим, возможно ли это сделать со всеми "фичами". Если вдруг в столбце 
вречается хотя бы 1 запись, не позволяющая произвести подобный перевод, напечатаем название этого столбца: 
'''


cols = ['seats', 'doors', 'Мощность', 'Крутящий момент двигателя', 
         'Разгон до сотни', 'Максимальная скорость', 'Дорожный просвет', 
         'Колёсная база', 'Объём багажника', 'Объём багажника максимальный', 
         'Объём топливного бака', 'Масса автомобиля', 'Двигатель значение', 
         'Коробка передач значение', 'Расход на 100 км город',
         'Расход на 100 км трасса', 'Расход на 100 км смешанный', 
         'Габариты длина', 'Габариты ширина', 'Габариты высота']

for col in cols:
    try:
        df[f"{col}"] = df[f"{col}"].astype(float)
    except:
        print(col)
# Out:
# Разгон до сотни

# %% [markdown]
# В столбце "Разгон до сотни" есть значения (забегая вперёд, это записи типа "нет"), которые невозможно привести к числовому виду. Избавимся от них

# %%
df = df[df['Разгон до сотни']!='нет'].reset_index()
df = df.drop('index', 1)

### Теперь приведём значения в последнем оставшемся столбце к числовому виду ###

df['Разгон до сотни'] = df['Разгон до сотни'].astype(float)

df
# Out:
#       brand     model               complect           type_car  seats  doors  \
# 0      Audi  A3 Sedan          1.4 TFSI 7AMT     Седан класса C    5.0    4.0
# 1      Audi  A3 Sedan    sport 1.4 TFSI 7AMT     Седан класса C    5.0    4.0
# 2      Audi  A3 Sedan          2.0 TFSI 7AMT     Седан класса C    5.0    4.0
# 3      Audi  A3 Sedan  2.0 TFSI 7AMT quattro     Седан класса C    5.0    4.0
# 4      Audi  A3 Sedan    sport 2.0 TFSI 7AMT     Седан класса C    5.0    4.0
# ...     ...       ...                    ...                ...    ...    ...
# 1627  Volvo      XC90      D5 AT 5S R-Design  Большой кроссовер    5.0    5.0
# 1628  Volvo      XC90      T6 AT 7S R-Design  Большой кроссовер    7.0    5.0
# 1629  Volvo      XC90      D5 AT 7S R-Design  Большой кроссовер    7.0    5.0
# 1630  Volvo      XC90   T8 AT 7S Inscription  Большой кроссовер    7.0    5.0
# 1631  Volvo      XC90      T8 AT 7S R-Design  Большой кроссовер    7.0    5.0
#
#       Мощность  Крутящий момент двигателя    Привод  Разгон до сотни  \
# 0        150.0                      250.0  передний              8.2
# 1        150.0                      250.0  передний              8.2
# 2        190.0                      320.0  передний              6.8
# 3        190.0                      320.0    полный              6.2
# 4        190.0                      320.0  передний              6.8
# ...        ...                        ...       ...              ...
# 1627     235.0                      480.0    полный              7.8
# 1628     320.0                      400.0    полный              6.5
# 1629     235.0                      480.0    полный              7.8
# 1630     407.0                      640.0    полный              5.6
# 1631     407.0                      640.0    полный              5.6
#
#       Максимальная скорость  Дорожный просвет  Колёсная база  Объём багажника  \
# 0                     224.0             165.0         2637.0            425.0
# 1                     224.0             165.0         2637.0            425.0
# 2                     250.0             165.0         2637.0            425.0
# 3                     242.0             165.0         2637.0            390.0
# 4                     242.0             165.0         2637.0            425.0
# ...                     ...               ...            ...              ...
# 1627                  220.0             237.0         2984.0            721.0
# 1628                  230.0             237.0         2984.0            692.0
# 1629                  220.0             237.0         2984.0            692.0
# 1630                  230.0             237.0         2984.0            640.0
# 1631                  230.0             237.0         2984.0            640.0
#
#       Объём багажника максимальный  Объём топливного бака  Масса автомобиля  \
# 0                            880.0                   50.0            1320.0
# 1                            880.0                   50.0            1320.0
# 2                            880.0                   50.0            1395.0
# 3                            845.0                   55.0            1465.0
# 4                            880.0                   50.0            1395.0
# ...                            ...                    ...               ...
# 1627                        1899.0                   71.0            1969.0
# 1628                        1899.0                   71.0            2004.0
# 1629                        1899.0                   71.0            2009.0
# 1630                        1899.0                   70.0            2350.0
# 1631                        1899.0                   70.0            2350.0
#
#      Двигатель тип  Двигатель значение Коробка передач тип  \
# 0       бензиновый              1395.0    роботизированная
# 1       бензиновый              1395.0    роботизированная
# 2       бензиновый              1984.0    роботизированная
# 3       бензиновый              1984.0    роботизированная
# 4       бензиновый              1984.0    роботизированная
# ...            ...                 ...                 ...
# 1627     дизельный              1969.0      автоматическая
# 1628    бензиновый              1969.0      автоматическая
# 1629     дизельный              1969.0      автоматическая
# 1630     гибридный              1969.0      автоматическая
# 1631     гибридный              1969.0      автоматическая
#
#       Коробка передач значение  Расход на 100 км город  \
# 0                          7.0                     5.9
# 1                          7.0                     5.9
# 2                          7.0                     7.2
# 3                          7.0                     7.2
# 4                          7.0                     7.2
# ...                        ...                     ...
# 1627                       8.0                     6.4
# 1628                       8.0                     0.0
# 1629                       8.0                     6.4
# 1630                       8.0                     0.0
# 1631                       8.0                     0.0
#
#       Расход на 100 км трасса  Расход на 100 км смешанный  Габариты длина  \
# 0                         4.1                         4.8          4458.0
# 1                         4.1                         4.8          4458.0
# 2                         4.7                         5.6          4458.0
# 3                         4.8                         5.7          4458.0
# 4                         4.7                         5.6          4458.0
# ...                       ...                         ...             ...
# 1627                      5.5                         5.8          4950.0
# 1628                      0.0                         8.3          4950.0
# 1629                      5.5                         5.8          4950.0
# 1630                      0.0                         2.1          4950.0
# 1631                      0.0                         2.1          4950.0
#
#       Габариты ширина  Габариты высота
# 0              1796.0           1416.0
# 1              1796.0           1416.0
# 2              1796.0           1416.0
# 3              1796.0           1416.0
# 4              1796.0           1416.0
# ...               ...              ...
# 1627           2008.0           1776.0
# 1628           2008.0           1776.0
# 1629           2008.0           1776.0
# 1630           2008.0           1776.0
# 1631           2008.0           1776.0
#
# [1632 rows x 27 columns]

# %%
### Удалим столбец "complect", ведь он дублирует другие столбцы ("двигатель" и "коробка передач")###

df = df.drop('complect', 1)

# %%
'''
Переведём категориальные и бинарные признаки в вид, 
корректно воспринимаемый алгоритмами машинного обучения, 
в дискретные значения:
'''

df = pd.get_dummies(df, columns = ["brand", "model", "Привод", "Двигатель тип", "Коробка передач тип"])

# %% [markdown]
# ### Сгрупируем данные по целевому признаку, типу кузова:

# %%
'''
Нам предстоит произвести много группировок, а столбцов стало в разы больше. 
Так что уменьшим количество  выводимых столбцов до, например, 5:
'''

pd.set_option('display.max_columns', 5)

### Сгрупируем по столбцу "type_car" ###

type_car_group_df = df.groupby("type_car").count().reset_index()
type_car_group_df
# Out:
#                                       type_car  seats  ...  \
# 0                          Большой внедорожник    123  ...
# 1                            Большой кроссовер    113  ...
# 2                         Внедорожник класса B      9  ...
# 3                                          Вэн     21  ...
# 4                       Горячий седан класса C      3  ...
# 5                     Горячий хэтчбек класса C      3  ...
# 6                    Кабриолет с мягкой крышей      5  ...
# 7                                   Компактвэн     39  ...
# 8                         Компактный кроссовер    375  ...
# 9                           Кроссовер класса B     24  ...
# 10                               Купе класса C      3  ...
# 11                               Купе класса D     16  ...
# 12                               Купе класса E      2  ...
# 13                                     Минивэн      2  ...
# 14                                       Пикап     18  ...
# 15                                     Родстер      9  ...
# 16                              Седан класса B     91  ...
# 17                              Седан класса C     53  ...
# 18                              Седан класса D     88  ...
# 19                              Седан класса E    101  ...
# 20                              Седан класса F     68  ...
# 21                                   Спорткупе     16  ...
# 22                          Спорткупе класса D      6  ...
# 23                         Спортседан класса D      2  ...
# 24                         Спортседан класса E      2  ...
# 25                 Среднеразмерный внедорожник     25  ...
# 26                   Среднеразмерный кроссовер    236  ...
# 27                          Универсал класса C     11  ...
# 28                          Универсал класса D     12  ...
# 29                          Универсал класса E     16  ...
# 30  Универсал повышенной проходимости класса D      8  ...
# 31  Универсал повышенной проходимости класса E      7  ...
# 32                            Хэтчбек класса A     10  ...
# 33                            Хэтчбек класса B     40  ...
# 34                            Хэтчбек класса C     29  ...
# 35                            Хэтчбек класса D     26  ...
# 36                            Хэтчбек класса E     20  ...
#
#     Коробка передач тип_механическая  Коробка передач тип_роботизированная
# 0                                123                                   123
# 1                                113                                   113
# 2                                  9                                     9
# 3                                 21                                    21
# 4                                  3                                     3
# 5                                  3                                     3
# 6                                  5                                     5
# 7                                 39                                    39
# 8                                375                                   375
# 9                                 24                                    24
# 10                                 3                                     3
# 11                                16                                    16
# 12                                 2                                     2
# 13                                 2                                     2
# 14                                18                                    18
# 15                                 9                                     9
# 16                                91                                    91
# 17                                53                                    53
# 18                                88                                    88
# 19                               101                                   101
# 20                                68                                    68
# 21                                16                                    16
# 22                                 6                                     6
# 23                                 2                                     2
# 24                                 2                                     2
# 25                                25                                    25
# 26                               236                                   236
# 27                                11                                    11
# 28                                12                                    12
# 29                                16                                    16
# 30                                 8                                     8
# 31                                 7                                     7
# 32                                10                                    10
# 33                                40                                    40
# 34                                29                                    29
# 35                                26                                    26
# 36                                20                                    20
#
# [37 rows x 296 columns]

# %% [markdown]
# ### В результате группировки можно обратить внимание, что в датасете 37 уникальных типов кузовов, с подклассами. По заданию же требуется проводить классификацию только лишь на 4 класса. Так что модифицируем колонку *type_car*, избавимся от деления на подклассы.

# %%
### Проверим вхождение названий 4 классов в строки таблицы и произведём соответствующие замены ###


df["type_car"] = df["type_car"].apply(lambda x: x.replace(x, "седан") if "седан" in x or "Седан" in x else x)
df["type_car"] = df["type_car"].apply(lambda x: x.replace(x, "кроссовер") if "кроссовер" in x or "Кроссовер" in x else x)
df["type_car"] = df["type_car"].apply(lambda x: x.replace(x, "хэтчбек") if "хэтчбек" in x or "Хэтчбек" in x else x)
df["type_car"] = df["type_car"].apply(lambda x: x.replace(x, "внедорожник") if "внедорожник" in x or "Внедорожник" in x else x)

df.groupby("type_car").count().reset_index()
# Out:
#                                       type_car  seats  ...  \
# 0                                          Вэн     21  ...
# 1                    Кабриолет с мягкой крышей      5  ...
# 2                                   Компактвэн     39  ...
# 3                                Купе класса C      3  ...
# 4                                Купе класса D     16  ...
# 5                                Купе класса E      2  ...
# 6                                      Минивэн      2  ...
# 7                                        Пикап     18  ...
# 8                                      Родстер      9  ...
# 9                                    Спорткупе     16  ...
# 10                          Спорткупе класса D      6  ...
# 11                          Универсал класса C     11  ...
# 12                          Универсал класса D     12  ...
# 13                          Универсал класса E     16  ...
# 14  Универсал повышенной проходимости класса D      8  ...
# 15  Универсал повышенной проходимости класса E      7  ...
# 16                                 внедорожник    157  ...
# 17                                   кроссовер    748  ...
# 18                                       седан    408  ...
# 19                                     хэтчбек    128  ...
#
#     Коробка передач тип_механическая  Коробка передач тип_роботизированная
# 0                                 21                                    21
# 1                                  5                                     5
# 2                                 39                                    39
# 3                                  3                                     3
# 4                                 16                                    16
# 5                                  2                                     2
# 6                                  2                                     2
# 7                                 18                                    18
# 8                                  9                                     9
# 9                                 16                                    16
# 10                                 6                                     6
# 11                                11                                    11
# 12                                12                                    12
# 13                                16                                    16
# 14                                 8                                     8
# 15                                 7                                     7
# 16                               157                                   157
# 17                               748                                   748
# 18                               408                                   408
# 19                               128                                   128
#
# [20 rows x 296 columns]

# %% [markdown]
# После преобразования оказалось, что остались и другие типы кузова, которые не являются ничем из __Седан - Хетчбек - Кроссовер - Внедорожник__. В таком случае есть несколько вариантов фильтрации. Сделаем копии датафрейма для обработки разных вариантов фильтрации оставшихся типов кузова

# %%
### Удалены все записи, не относяшиеся к классам из ТЗ ###
df_4types = df.copy(deep=True)

### Агрегация оставшихся типов кузова в соответствующие классы из ТЗ ###
df_4types_plus = df.copy(deep=True)

### 4 класса из ТЗ + все оставшиеся типы кузова агрегированы в класс "другой кузов" ###
df_5types = df.copy(deep=True)

### 4 класса из ТЗ + 4 класса остальных (Вэн, Компактвэн и Минивэн объединены в класс "многоместный") ###
df_all_types = df.copy(deep=True)

# %%
### Удалим ненужную копию, чтобы освободить память ###

del df

# %%
'''
Сохраним только те записи, в которых класс соответствует класса из ТЗ, 
а после сгруппируем по тому же столбцу, чтобы проверить результат выполнения ячейки:
'''

df_4types = df_4types.loc[df_4types['type_car'].isin(["седан", "кроссовер", "хэтчбек", "внедорожник"])]

df_4types.groupby("type_car").count().reset_index()
# Out:
#       type_car  seats  ...  Коробка передач тип_механическая  \
# 0  внедорожник    157  ...                               157
# 1    кроссовер    748  ...                               748
# 2        седан    408  ...                               408
# 3      хэтчбек    128  ...                               128
#
#    Коробка передач тип_роботизированная
# 0                                   157
# 1                                   748
# 2                                   408
# 3                                   128
#
# [4 rows x 296 columns]

# %%
'''
- На самом деле, различий между купе и седаном особо нет 
(см. https://favorit-motors.ru/articles/vybor-avtomobilya/kupe/), 
так что будем считать это одним и тем же классом. 
Родстер - своего рода тоже седан (см. https://ru.wikipedia.org/wiki/%D0%A0%D0%BE%D0%B4%D1%81%D1%82%D0%B5%D1%80),
аналогично и с кабриолетом, которые в большинстве своём являются двухдверными автомобилями.

- Разница между универсалом и хэтчбеком заключается исключительно в размере багажника 
(см. https://favorit-motors.ru/articles/vybor-avtomobilya/universal/), так что их тоже - с определённой скидкой -
можно считать одинаковым типом.

- Подобно предыдущему случаю, разница между внедорожником и пикапом тоже в багажнике - 
она даже менее значительная - так что объединим в один класс
'''

df_4types_plus["type_car"] = df_4types_plus["type_car"].apply(lambda x: x.replace(x, "седан") if "Купе" in x or "купе" in x or "Родстер" in x or "Кабриолет" in x else x)
df_4types_plus["type_car"] = df_4types_plus["type_car"].apply(lambda x: x.replace(x, "хэтчбек") if "Универсал" in x else x)
df_4types_plus["type_car"] = df_4types_plus["type_car"].apply(lambda x: x.replace(x, "внедорожник") if "Пикап" in x else x)

df_4types_plus = df_4types_plus.loc[df_4types_plus['type_car'].isin(["седан", "кроссовер", "хэтчбек", "внедорожник"])]

df_4types_plus.groupby("type_car").count().reset_index()
# Out:
#       type_car  seats  ...  Коробка передач тип_механическая  \
# 0  внедорожник    175  ...                               175
# 1    кроссовер    748  ...                               748
# 2        седан    465  ...                               465
# 3      хэтчбек    182  ...                               182
#
#    Коробка передач тип_роботизированная
# 0                                   175
# 1                                   748
# 2                                   465
# 3                                   182
#
# [4 rows x 296 columns]

# %%
### Заменяем в колонке type_car все записи, кроме соотв. классов из ТЗ, на "другой кузов" ###

df_5types["type_car"] = df_5types["type_car"].apply(lambda x: x.replace(x, "другой кузов") if "внедорожник"!=x and "кроссовер"!=x and "седан"!=x and "хэтчбек"!=x else x)

df_5types.groupby("type_car").count().reset_index()
# Out:
#        type_car  seats  ...  Коробка передач тип_механическая  \
# 0   внедорожник    157  ...                               157
# 1  другой кузов    191  ...                               191
# 2     кроссовер    748  ...                               748
# 3         седан    408  ...                               408
# 4       хэтчбек    128  ...                               128
#
#    Коробка передач тип_роботизированная
# 0                                   157
# 1                                   191
# 2                                   748
# 3                                   408
# 4                                   128
#
# [5 rows x 296 columns]

# %%
### Добавляем к классам из ТЗ "купе", "универсал", "многоместный" и "Пикап" ###

df_all_types["type_car"] = df_all_types["type_car"].apply(lambda x: x.replace(x, "универсал") if "Универсал" in x else x)
df_all_types["type_car"] = df_all_types["type_car"].apply(lambda x: x.replace(x, "купе") if "купе" in x or "Купе" in x or "Родстер" in x or "Кабриолет" in x else x)
df_all_types["type_car"] = df_all_types["type_car"].apply(lambda x: x.replace(x, "многоместный") if "Вэн" in x or "вэн" in x else x)

df_all_types.groupby("type_car").count().reset_index()
# Out:
#        type_car  seats  ...  Коробка передач тип_механическая  \
# 0         Пикап     18  ...                                18
# 1   внедорожник    157  ...                               157
# 2     кроссовер    748  ...                               748
# 3          купе     57  ...                                57
# 4  многоместный     62  ...                                62
# 5         седан    408  ...                               408
# 6     универсал     54  ...                                54
# 7       хэтчбек    128  ...                               128
#
#    Коробка передач тип_роботизированная
# 0                                    18
# 1                                   157
# 2                                   748
# 3                                    57
# 4                                    62
# 5                                   408
# 6                                    54
# 7                                   128
#
# [8 rows x 296 columns]

# %% [markdown]
# ## Вспомогательный код:

# %%
df_all_types.to_csv("df_all_types.csv")
df_5types.to_csv("df_5types.csv")
df_4types_plus.to_csv("df_4types_plus.csv")
df_4types.to_csv("df_4types.csv")

# %% [markdown]
# ## Работа с моделями

# %%
### Заменим записи в колонке целевой переменной на индексы классов для корректной работы моделей ###

import numpy as np 

df_4types['type_car'] = df_4types['type_car'].map({'внедорожник': 0, 
                                                   'кроссовер': 1, 
                                                   'седан': 2, 
                                                   'хэтчбек': 3}) 

df_4types_plus['type_car'] = df_4types_plus['type_car'].map({'внедорожник': 0, 
                                                             'кроссовер': 1, 
                                                             'седан': 2, 
                                                             'хэтчбек': 3}) 

df_5types['type_car'] = df_5types['type_car'].map({'внедорожник': 0, 
                                                   'кроссовер': 1, 
                                                   'седан': 2, 
                                                   'хэтчбек': 3, 
                                                   'другой кузов': 4})

df_all_types['type_car'] = df_all_types['type_car'].map({'внедорожник': 0, 
                                                         'кроссовер': 1, 
                                                         'седан': 2, 
                                                         'хэтчбек': 3, 
                                                         'Пикап': 4,
                                                         'купе': 5,
                                                         'универсал': 6,
                                                         'многоместный': 7})

# %%
''' 
Будем работать с таблицей, в которой содержатся записи только тех классов, которые 
были указаны в ТЗ, без агрегации с остальными. Однако весь пайплайн обучения будет 
абсолютно идентичным и для других фреймов.
'''

X = df_4types.drop("type_car", axis=1)
y = df_4types["type_car"].astype('int')

# %%
### Разделим данные на тренировочные (для обучения) и валидационные (для определения качества) ###

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# !pip install imblearn
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.8.0-py3-none-any.whl (206 kB)
# Requirement already satisfied: scikit-learn>=0.24 in c:\users\rtm51\anaconda3\anaconda4\lib\site-packages (from imbalanced-learn->imblearn) (0.24.2)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\rtm51\appdata\roaming\python\python38\site-packages (from imbalanced-learn->imblearn) (1.7.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\rtm51\anaconda3\anaconda4\lib\site-packages (from imbalanced-learn->imblearn) (1.0.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\rtm51\anaconda3\anaconda4\lib\site-packages (from imbalanced-learn->imblearn) (1.21.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\rtm51\anaconda3\anaconda4\lib\site-packages (from scikit-learn>=0.24->imbalanced-learn->imblearn) (2.1.0)
# Installing collected packages: imbalanced-learn, imblearn
# Successfully installed imbalanced-learn-0.8.0 imblearn-0.0

# %% [markdown]
# Как выяснились после группировки данных по полю __type_car__, наш набор данных несбалансирован: превалируют классы *кроссовер* и *седан*. Из-за этого необходимо стандартизировать признаковое пространство через **StandardScaler** и применить **RandomUnderSampler**, который представляет из себя - выдрежка из документации - способ сбалансировать данные путем случайного выбора подмножества данных для целевых классов

# %%
from imblearn.under_sampling import RandomUnderSampler
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)

rus = RandomUnderSampler()
X_train_rus, y_train_rus = rus.fit_resample(X_train, y_train)

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.4.2-py3-none-win_amd64.whl (97.8 MB)
# Requirement already satisfied: numpy in c:\users\rtm51\anaconda3\anaconda4\lib\site-packages (from xgboost) (1.21.1)
# Requirement already satisfied: scipy in c:\users\rtm51\appdata\roaming\python\python38\site-packages (from xgboost) (1.7.1)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.4.2

# %% [markdown]
# ### В качестве моделей машинного будут использоваться:
#
# 1.   **Logistic Regression**, являющаяся одной из самых первых(фундоментальных) моделей классификации, с которыми знакомятся в задаче классификации. К тому же на её основе строится объяснение работы нейрона и нейронной сети. Так что стало интересно, как такой, с виду базовый, алгоритм себя покажет в реальной задаче.
# 2.   **XGBoost**, причины выбора которого, во-первых, совпадают с его широкой распространённостью и популярностью в интернете (например, во многих соревнованиях Kaggle именно эту модель используют в реализациях), во-вторых, так как он обладает возможностью понять, какие признаки являются наиболее важными в наборе данных (*plot_importance*)
# 3.   **Gaussian Naive Bayes**, который может быть удивительно быстрым, точным и простым в реализации, но в то же время обладает недостатком в своей концепции, который в кейсе данной курсовой может негативно сыграть на результатах метрик (требование к независимости признаков), так что решено проверить его работу в том числе.
# 4.   **DecisionTreeClassifier**, хорошо интерпретируемый в бизнес-кейсах, например, банковские скоринговые системы.  В нашем случае он также может быть к месту. К тому же многие статьи, охватывающие задачу классификации автомобилей, включают в себя использование именно этой модели.

# %%
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_validate

lr = LogisticRegression()
xgb = XGBClassifier()
gnb = GaussianNB()
dtc = DecisionTreeClassifier()

'''
Проверим на кросс-валидации, какое качество (accuracy/доля правильных ответов) на ТРЕНИРОВОЧНЫХ данных
покажет каждая из моделей. Выбранная метрика используется достаточно редко (можно было бы использовать, 
например, precision, recall или F-score, которые гораздо чаще применяются. Однако из-за отсутствия 
каких-либо уточнений в специфике кейса, который мы стремимся решить, решено для общности использовать 
всё-таки accuracy.
'''

model_a = []
cross_val_a = []
accuracy = []

### Сохраняем название каждой модели и скор на кросс-валидации ###

for i in (lr, xgb, gnb, dtc):
    model_a.append(i.__class__.__name__)
    cross_val_a.append(cross_validate(i, X_train_rus, y_train_rus, scoring="accuracy"))

for d in range(len(cross_val_a)):
    accuracy.append(cross_val_a[d]['test_score'].mean())
    
accuracy_arr = np.array(accuracy)
model_recall = pd.DataFrame
pd.DataFrame(data=accuracy_arr, index=model_a, columns=["accuracy"])
# Out:
# [14:48:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:48:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:48:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:48:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:48:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#                         accuracy
# LogisticRegression      0.970702
# XGBClassifier           0.989333
# GaussianNB              0.856281
# DecisionTreeClassifier  0.970667

# %% [markdown]
# ### GridSearchCV для определения наилучших гиперпараметров (результаты запусков не поспособствовали улучшению качества моделей, так что данный  этап игнорируется)

# %%
from sklearn.model_selection import GridSearchCV

# Logistic Regression

param_grid = {'solver': ['newton-cg', 'lbfgs', 'liblinear'], 'C': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100]}
grid_search = GridSearchCV(lr, param_grid, scoring='accuracy')
grid_result = grid_search.fit(X_train_rus, y_train_rus)
print(f'Best result: {grid_result.best_score_} for {grid_result.best_params_}')
# Out:
# Best result: 0.970701754385965 for {'C': 0.01, 'solver': 'newton-cg'}

# %%
# XGBoost

param_grid = {'n_estimators': range(0,1000,25)}
grid_search = GridSearchCV(xgb, param_grid, scoring='accuracy')
grid_result = grid_search.fit(X_train_rus, y_train_rus)
print(f'Best result: {grid_result.best_score_} for {grid_result.best_params_}')
# Out:
# [14:13:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:13:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:24] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:14:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:16] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:17] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:18] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:19] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:28] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:48] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:55] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:15:59] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:16:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:16:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:16:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:16:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:16:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:16:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:16:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:16:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:16:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:16:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [14:16:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Best result: 0.9893333333333333 for {'n_estimators': 25}

# %%
xgb = XGBClassifier(n_estimators=25)
param_grid = {'max_depth': range(1,8,1), 'min_child_weight': np.arange(0.0001, 0.5, 0.001)}
grid_search = GridSearchCV(xgb, param_grid, scoring='accuracy', n_jobs=-1)
grid_result = grid_search.fit(X_train_rus, y_train_rus)
print(f'Best result: {grid_result.best_score_} for {grid_result.best_params_}')
# Out:
# [14:36:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Best result: 0.9813333333333333 for {'max_depth': 4, 'min_child_weight': 0.48009999999999997}

# %%
xgb = XGBClassifier(n_estimators=25)
param_grid = {'gama': np.arange(0.0,20.0,0.05)}
grid_search = GridSearchCV(xgb, param_grid, scoring='accuracy', n_jobs=-1)
grid_result = grid_search.fit(X_train_rus, y_train_rus)
print(f'Best result: {grid_result.best_score_} for {grid_search.best_params_}')
# Out:
# [14:45:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:573:
# Parameters: { "gama" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [14:45:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Best result: 0.9893333333333333 for {'gama': 0.0}

# %%
# DecisionTreeClassifier

param_grid = {'max_depth': range(1,15), 'max_features': range(2,40)}
grid_search = GridSearchCV(dtc, param_grid, scoring='accuracy')
grid_result = grid_search.fit(X_train_rus, y_train_rus)
print(f'Best result: {grid_result.best_score_} for {grid_result.best_params_}')
# Out:
# Best result: 0.9654035087719299 for {'max_depth': 13, 'max_features': 32}

# %%
dtc = DecisionTreeClassifier(max_depth=13, max_features=32)

param_grid = {"criterion": ['gini', "entropy"], "splitter": ["best", "random"]}
grid_search = GridSearchCV(dtc, param_grid, scoring='accuracy')
grid_result = grid_search.fit(X_train_rus, y_train_rus)
print(f'Best result: {grid_result.best_score_} for {grid_result.best_params_}')
# Out:
# Best result: 0.9468771929824561 for {'criterion': 'gini', 'splitter': 'best'}

# %% [markdown]
# ## Проверка на валидации

# %%
### Трансформируем тестовый набор и вычислим score каждой модели на валидации ###

X_test_ = scaler.transform(X_test)

lr = LogisticRegression()
xgb = XGBClassifier()
gnb = GaussianNB()
dtc = DecisionTreeClassifier()

### Будем записывать в словарь пары ключ(модель) : скор на тестовой выборке ###

results = {}
for model in (lr, xgb, gnb, dtc):
    model.fit(X_train_rus, y_train_rus)
    pred = model.predict(X_test_)
    metric = accuracy_score(y_test, pred)
    results[f"{model.__class__.__name__}"] = metric
# Out:
# [15:04:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
pd.DataFrame(results.items(), 
             columns=['model', 'accuracy']).sort_values(by=["accuracy"], 
             ascending=False).set_index('model')
# Out:
#                         accuracy
# model
# GaussianNB              0.764543
# DecisionTreeClassifier  0.121884
# LogisticRegression      0.113573
# XGBClassifier           0.113573

# %% [markdown]
# Результаты удручают. Очень низкий *accuracy*. НО: все модели с низким "скором" так или иначе зависят от размерности признакового пространства, а оно у нас после всех модицикаций стало очень большим (из +- 30 фичей стало почти 300). Так что посмотрим на то, какие именно признаки действительно влияют на классификацию.

# %%
from xgboost import plot_importance
import operator

### Будем в словарь записывать пары ключ (название признака) : соотв. значение ###

importance = {}
for col,score in zip(X.columns, xgb.feature_importances_):
    importance[col] = score

### Теперь отсортируем этот словарь по значениям и удалим все пары с нулевыми значениями ###
sorted_imp = dict(sorted(importance.items(), key=operator.itemgetter(1),reverse=True))
wiped_imp = {k: v for k, v in sorted_imp.items() if v}

# %% [markdown]
# ## Исключили признаки, которые не влияют на результат. Теперь повторим весб пайплайн, но в этот раз только лишь с теми признаками, которые дейсвительно влияют на классификацию

# %%
X = df_4types[wiped_imp.keys()]
y = df_4types["type_car"].astype('int')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
scaler = StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)

rus = RandomUnderSampler()
X_train_rus, y_train_rus = rus.fit_resample(X_train, y_train)

# %%
lr = LogisticRegression()
xgb = XGBClassifier()
gnb = GaussianNB()
dtc = DecisionTreeClassifier()

model_a = []
cross_val_a = []
accuracy = []
for i in (lr, xgb, gnb, dtc):
    model_a.append(i.__class__.__name__)
    cross_val_a.append(cross_validate(i, X_train_rus, y_train_rus, scoring="accuracy"))

for d in range(len(cross_val_a)):
    accuracy.append(cross_val_a[d]['test_score'].mean())
    
accuracy_arr = np.array(accuracy)
model_recall = pd.DataFrame
pd.DataFrame(data=accuracy_arr, index=model_a, columns=["accuracy"])
# Out:
# [15:16:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:16:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:16:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:16:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [15:16:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#                         accuracy
# LogisticRegression      0.968105
# XGBClassifier           0.986737
# GaussianNB              0.819228
# DecisionTreeClassifier  0.989404

# %% [markdown]
# Пока рано делать какие-либо выводы. Поменялось значение только Байесовоского алгоритма, но всё равно слабо. Сделаем предсказания на тестовых данных и вычислим скор на валидации

# %%
X_test_ = scaler.transform(X_test)

lr = LogisticRegression()
xgb = XGBClassifier()
gnb = GaussianNB()
dtc = DecisionTreeClassifier()

results = {}
for model in (lr, xgb, gnb, dtc):
    model.fit(X_train_rus, y_train_rus)
    pred = model.predict(X_test_)
    metric = accuracy_score(y_test, pred)
    results[f"{model.__class__.__name__}"] = metric
# Out:
# [15:17:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
pd.DataFrame(results.items(), 
             columns=['model', 'accuracy']).sort_values(by=["accuracy"], 
             ascending=False).set_index('model')
# Out:
#                         accuracy
# model
# XGBClassifier           0.986150
# DecisionTreeClassifier  0.975069
# LogisticRegression      0.969529
# GaussianNB              0.681440

# %% [markdown]
# Теперь по метрике accuracy на валидации просто отличные результаты! Байесовский алгоритм закономерно показывает результаты ниже, так как признаки всё таки коррелируют друг с другом (например, чем больше объём багажника, тем выше масса автомобиля; чем больше мощность двигателя тем больше - обычно - расход топлива и т.д.). Лучше всего себя показал XGBClassifier, являющийся по своей сути модификацией алгоритма деревьев решений, но с градиентным спуском.

# %% [markdown]
# В заключении повторюсь: идентичный пайплайн можно использовать и с другими таблицами, которые получились у нас после агрегации. В зависимости от задачии и конечной цели будет уместнее использовать тот или иной подход к этой самой агрегации и делении на классы. Также вероятно всего в случае изменения датасета поменяется и пул признаков, которые влияют на предсказание, так что feature_importance нужно будет пересчитать.
